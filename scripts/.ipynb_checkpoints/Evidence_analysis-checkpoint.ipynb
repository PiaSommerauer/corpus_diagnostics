# %%
import utils
import relations

import pandas as pd
import os
import csv

from collections import defaultdict

pd.set_option('display.max_rows', None)


def get_overview(metrics, level, model_name, evidence_type):
    path_dir = f'../analysis/{model_name}/{level}'
    overview_dict = defaultdict(dict)
    if level == 'properties':
        target = 'property'
    elif level == 'relations':
        target = 'relation'
    for metric in metrics:
        path = f'{path_dir}/{metric}.csv'
        with open(path) as infile:
            data = list(csv.DictReader(infile))
        for d in data:
            if target in d:
                prop = d[target]
            else:
                prop = d['']
            sc = d[evidence_type]
            if sc == '':
                sc = 0
            overview_dict[prop][metric] = float(sc)
    df = pd.DataFrame(overview_dict)
    return df.T

# %% [markdown]
# # Overview properties

# %% [markdown]
# ## Giga

# %%
metrics = ['proportion', 'diversity', 'coherence',
           #, 'coherence', 
           'dist-mean', 'dist-max', 
           'str-mean', 'str-max'
          ]
level = 'properties'
evidence_type = 'u'
model_name = 'giga_full_updated'
df = get_overview(metrics, level, model_name, evidence_type)
df = utils.raw_to_distance(df, score_names = metrics, reference_name = 'median', 
                            score = 'dist-percent', sum_scores = ['sum', 'bin'])

df = df.sort_values('sum', ascending=False)
#print(df[3:7].round(4).to_latex())
df
# Out:
#                   proportion   diversity  coherence  dist-mean  dist-max  \
# median-reference    0.921154  722.000000   0.100993   0.614247  0.822578
# roll                0.043960    4.174515  -0.087623   0.058955  0.085406
# square              0.039399    0.994460   0.014600   0.048517  0.215691
# warm                0.023252    1.750693  -0.086445  -0.194613 -0.069380
# blue                0.003471    1.860111  -0.082255   0.068068  0.103284
# cold                0.012285    0.396122  -0.014383  -0.054938  0.091753
# red                 0.026615    1.314404  -0.066213  -0.135015  0.049739
# juicy              -0.051110   -0.019391   0.123604  -0.016785 -0.013744
# black               0.031740    0.512465  -0.044269  -0.052819 -0.061746
# swim                0.043146    0.837950  -0.091815  -0.118913  0.125639
# dangerous          -0.044014    0.358726  -0.022628   0.023717  0.047488
# fly                 0.027438    0.247922  -0.041984   0.082839  0.215691
# round              -0.002088   -0.337950  -0.016459  -0.062546  0.029101
# median              0.000000    0.000000   0.000000   0.000000  0.000000
# wheels             -0.092371   -0.717452   0.051656   0.016785  0.008647
# hot                -0.237499   -0.918283   0.324989  -0.061395 -0.109204
# lay_eggs           -0.237149   -0.927978   0.173515   0.066399 -0.030829
# female             -0.324519   -0.961219   0.341013   0.078716 -0.064769
# green              -0.094711   -0.332410   0.091076  -0.069458 -0.043168
# wings              -0.083060   -0.344875   0.031700  -0.030462 -0.043255
# made_of_wood        0.016537    0.019391  -0.120620  -0.123172 -0.036264
# yellow              0.002088   -0.933518   0.108571   0.150730 -0.008647
# used_in_cooking    -0.614728   -0.718837   0.094359   0.140142  0.065836
# sweet              -0.565762   -0.980609   0.014383   0.077229 -0.105787
#
#                   str-mean   str-max         sum       bin
# median-reference  0.002555  0.028974  103.498643  1.000000
# roll             -0.139451  0.354987    0.641536  0.714286
# square            0.234612  1.197943    0.392175  1.000000
# warm             -0.008776  0.984035    0.342681  0.428571
# blue             -0.291829  0.252356    0.273315  0.714286
# cold              0.386357  0.976742    0.256277  0.714286
# red              -0.288636  0.042667    0.134795  0.571429
# juicy             0.402592  0.450158    0.125047  0.428571
# black            -0.086024  0.328263    0.089659  0.428571
# swim             -0.230697  0.006234    0.081649  0.571429
# dangerous         0.008776 -0.006234    0.052262  0.571429
# fly              -0.281218  0.101471    0.050309  0.714286
# round             0.216459  0.248654    0.010739  0.428571
# median            0.000000  0.000000    0.000000  0.000000
# wheels            0.528527 -0.006953   -0.030166  0.571429
# hot               0.942979 -0.524042   -0.083208  0.285714
# lay_eggs          0.810516 -0.480929   -0.089494  0.428571
# female            0.595431 -0.294322   -0.089953  0.428571
# green             0.128155 -0.371678   -0.098885  0.285714
# wings            -0.018195 -0.442577   -0.132961  0.142857
# made_of_wood     -0.133506 -0.592800   -0.138634  0.285714
# yellow            0.143436 -0.708607   -0.177993  0.571429
# used_in_cooking  -0.087077 -0.288971   -0.201325  0.428571
# sweet            -0.064770 -0.836510   -0.351689  0.285714

# %%
metrics = ['proportion', 'diversity', 'coherence', 
           'dist-mean', 'dist-max', 
           'str-mean', 'str-max']
level = 'properties'
evidence_type = 'prop-specific'
model_name = 'giga_full_updated'
df = get_overview(metrics, level, model_name, evidence_type)
df = utils.raw_to_distance(df, score_names = metrics, reference_name = 'median', 
                           score = 'dist-percent', sum_scores = ['sum', 'bin'])
#df['sum'] = df.sum(axis=1)
df = df.sort_values('sum', ascending=False)
#print(df.round(2).fillna('-').to_latex())
#df.round(2)
df
# Out:
#                   proportion  diversity  coherence  dist-mean  dist-max  \
# female             11.531947        0.2   0.673054  -0.152607 -0.123384
# sweet               9.741669       -0.2   0.351083   0.096445  0.121969
# dangerous           2.881079        8.2  -0.310735  -0.033313  0.060196
# hot                 5.713543        0.2  -0.193906  -0.027047 -0.019015
# juicy              -0.535854       -0.2   0.840266   0.060196  0.000000
# lay_eggs            4.080519       -0.2   1.395491   0.111017  0.063633
# used_in_cooking     1.629080        2.2   0.110738   0.101309  0.174255
# median-reference    0.005320        2.5   0.346576   0.747309  0.792711
# wheels              2.081626        0.6   0.112627   0.060358  0.063682
# yellow              2.614985       -0.6        NaN   0.057362 -0.003198
# fly                 0.777114        2.6   0.000000   0.115241  0.136288
# wings               1.349740        1.8   0.130016   0.015613  0.076167
# made_of_wood       -0.043363        0.6   0.273504   0.000000  0.022206
# roll               -0.516141        3.0  -0.401124  -0.100272 -0.007925
# red                -0.893617       -0.6        NaN   0.063845  0.002913
# warm               -0.197051        2.6  -0.216870  -0.228328 -0.058309
# cold                0.043363        1.4  -0.028304  -0.111299 -0.023513
# median              0.000000        0.0   0.000000   0.000000  0.000000
# green              -0.674776       -0.6        NaN   0.148140  0.082381
# blue               -0.831711       -0.2  -0.154778  -0.048678 -0.032640
# black              -0.672795       -0.2  -0.559561  -0.056959 -0.053352
# round              -0.277003       -0.2  -0.640938  -0.212683 -0.140819
# swim               -0.863882       -0.6        NaN  -0.099918 -0.151470
# square                   NaN        NaN        NaN        NaN       NaN
#
#                   str-mean   str-max       sum       bin
# female           -0.383965 -0.444442  1.614372  0.428571
# sweet             0.173015  0.177552  1.494533  0.857143
# dangerous        -0.565670 -0.326370  1.415027  0.428571
# hot               1.548077  0.830291  1.150278  0.571429
# juicy             3.304115  3.376023  0.977821  0.571429
# lay_eggs          0.431466 -0.055215  0.832416  0.714286
# used_in_cooking   0.308937  0.531356  0.722239  1.000000
# median-reference  0.007886  0.014082  0.630555  1.000000
# wheels            0.483590  0.505446  0.558190  1.000000
# yellow            0.905098  0.066838  0.506848  0.666667
# fly              -0.459029 -0.405690  0.394846  0.571429
# wings            -0.270328 -0.406533  0.384953  0.714286
# made_of_wood      0.787838  0.732948  0.339019  0.714286
# roll             -0.343019  0.107508  0.248432  0.285714
# red               2.087792  0.729136  0.231678  0.666667
# warm             -0.498389 -0.398575  0.143211  0.142857
# cold             -0.135655 -0.197998  0.135228  0.285714
# median            0.000000  0.000000  0.000000  0.000000
# green             0.913020  0.071274 -0.009994  0.666667
# blue             -0.012819 -0.096009 -0.196662  0.000000
# black             0.000000  0.000000 -0.220381  0.000000
# round            -0.397955 -0.411264 -0.325809  0.000000
# swim             -0.560605 -0.753943 -0.504970  0.000000
# square                 NaN       NaN       NaN  0.000000

# %% [markdown]
# # Both models

# %%
from collections import defaultdict
import numpy as np
import csv
import os

metrics = [
        'proportion', 
        'diversity', 
           'coherence', 
           'dist-mean', 'dist-max', 
           'str-mean', 'str-max'
]

level = 'properties'
evidence_types = ['all', 'prop-specific', 'non-specific', 'u']

model_name = 'wiki_updated'
model_name_d = 'wiki_corpus'
# model_name = 'giga_full_updated'
# model_name_d = 'giga_corpus'
# load diagnostic results
path = '../data/diagnostic_classification/selectivity-giga_corpus_wiki_corpus_googlenews.csv'
df_d = pd.read_csv(path, index_col=0)


model_dict = defaultdict(dict)
new_model_dict = dict()

for evidence_type in evidence_types:
    df = get_overview(metrics, level, model_name, evidence_type)
    df = utils.raw_to_distance(df, score_names = metrics, reference_name = 'median', 
                           score = 'dist-percent', sum_scores = ['sum', 'bin'])
    
    learned = df_d[model_name_d]['learned'].split(' ')
    not_learned = df_d[model_name_d]['not learned'].split(' ')
    for i, row in df.iterrows():
        model_dict[i][f'{evidence_type}-sum'] = round(row['sum'], 2)
        model_dict[i][f'{evidence_type}-bin'] = round(row['bin'], 2)
for p, d in model_dict.items():
    if p not in ['median', 'median-reference']:
        if p in learned:
            diag = True
        elif p in not_learned:
            diag = False
        elif p == 'female':
            diag = True
        d = model_dict[p]
        d[f'cl'] = diag
        enough_scores = set()
        evidence_types_enough = set()
        for e in evidence_types:
            s = d[f'{e}-sum']
            b = d[f'{e}-bin']
            if s > 0.0 and b > 0.5:
                enough_scores.add(True)
                evidence_types_enough.add(e)
        d['et_enough'] = ' '.join(sorted(list(evidence_types_enough)))
        new_model_dict[p] = d

             
df = pd.DataFrame(new_model_dict).T.fillna('-')
# print(df.to_latex())    
#print(df.to_latex())
path_dir = '../analysis/diagnostic_classification'
os.makedirs(path_dir, exist_ok=True)
df.to_csv(f'{path_dir}/comparison-{model_name}.csv')

df.sort_values('cl')
# Out:
#                  all-sum  all-bin prop-specific-sum  prop-specific-bin  \
# warm                0.22     0.29             -0.11               0.43
# black               0.06     0.29             -0.03               0.29
# red                 0.10     0.14             -0.02               0.50
# round               0.11     0.29             -0.23               0.14
# cold                0.03     0.57             -0.25               0.00
# sweet               0.15     0.57              1.09               0.83
# hot                 0.04     0.43              2.57               0.71
# roll                0.81     0.57              0.31               0.43
# green              -0.08     0.43             -0.17               0.50
# blue                0.29     0.43             -0.13               0.50
# square              0.08     0.57                 -               0.00
# wheels              0.27     0.71              1.45               0.86
# female              0.07     0.71              0.49               0.43
# yellow             -0.20     0.14                 -               0.00
# juicy               0.09     0.57              0.81               0.67
# lay_eggs            0.19     0.43                 -               0.00
# used_in_cooking     0.25     0.86              0.57               0.86
# wings              -0.09     0.14              0.42               0.71
# dangerous           0.02     0.43              0.08               0.29
# fly                -0.10     0.57              2.22               0.71
# made_of_wood       -0.11     0.00              0.72               0.71
# swim                0.23     0.29             -0.28               0.14
#
#                  non-specific-sum  non-specific-bin  u-sum  u-bin     cl  \
# warm                         0.10              0.43   0.42   0.57  False
# black                       -0.18              0.14   0.22   0.43  False
# red                          0.07              0.29   0.16   0.43  False
# round                       -0.01              0.57   0.28   0.57  False
# cold                        -0.25              0.14   0.19   0.71  False
# sweet                        0.79              0.71  -0.30   0.29  False
# hot                          0.28              0.86  -0.09   0.29  False
# roll                         0.14              0.29   1.08   0.71  False
# green                        0.11              0.29  -0.06   0.29  False
# blue                         0.26              0.43   0.37   0.57  False
# square                       0.21              0.71  -0.00   0.71   True
# wheels                       0.67              0.86   0.13   0.71   True
# female                       0.44              0.86  -0.09   0.57   True
# yellow                      -0.24              0.29  -0.14   0.43   True
# juicy                        0.42              0.71  -0.01   0.43   True
# lay_eggs                     0.67              0.57   0.20   0.43   True
# used_in_cooking              1.48              1.00   0.01   0.57   True
# wings                        0.08              0.57  -0.02   0.57   True
# dangerous                    0.11              0.43   0.12   0.57   True
# fly                          0.28              0.57  -0.14   0.29   True
# made_of_wood                -0.14              0.00  -0.09   0.29   True
# swim                         0.04              0.29   0.37   0.57   True
#
#                                         et_enough
# warm                                            u
# black
# red
# round                                           u
# cold                                        all u
# sweet              all non-specific prop-specific
# hot                    non-specific prop-specific
# roll                                        all u
# green
# blue                                            u
# square                           all non-specific
# wheels           all non-specific prop-specific u
# female                           all non-specific
# yellow
# juicy              all non-specific prop-specific
# lay_eggs                             non-specific
# used_in_cooking  all non-specific prop-specific u
# wings                  non-specific prop-specific
# dangerous                                       u
# fly                    non-specific prop-specific
# made_of_wood                        prop-specific
# swim                                            u

# %%
# compare evidence type scores

def get_comparison_evidence(evidence_type, model_name, metrics):
    
    path_dir = '../analysis/diagnostic_classification'
    df = pd.read_csv(f'{path_dir}/comparison-{model_name}.csv', index_col = 0)
    prop_dict = df.to_dict('index')
    
    level = 'properties'
    print(evidence_type)
    df_overview = get_overview(metrics, level, model_name, evidence_type)
    prop_overview_dict = df_overview.to_dict('index')
   
    new_df_dict_enough = dict()
    new_df_dict_not_enough = dict()
    df_total = dict()
    
    cl_dict = dict()

    for prop, d in prop_overview_dict.items():
        if prop not in ['median', 'median-reference']:
            cl = prop_dict[prop]['cl']
            if cl == False:
                new_df_dict_not_enough[(prop+'-'+evidence_type)] = d
                df_total[prop] = dict()
                df_total[prop].update(d)
                df_total[prop]['cl'] = cl

            else:
                et_types = prop_dict[prop]['et_enough']
                if type(et_types) == str:
                    if evidence_type in et_types:
                        new_df_dict_enough[(prop+'-'+evidence_type)] = d
                        df_total[prop] = dict()
                        df_total[prop].update(d)
                        df_total[prop]['cl'] = cl
            
            #df_total[prop]['i'] = i
            
           
    df_enough = pd.DataFrame(new_df_dict_enough).T.sort_index()

    df_mean = pd.DataFrame()

    df_mean[('mean', 'enough')] = df_enough.mean(axis = 0)
    df_mean[('median', 'enough' )] = df_enough.median(axis = 0)
    df_mean[('std', 'enough')] = df_enough.std(axis = 0)

    df_not_enough = pd.DataFrame(new_df_dict_not_enough).T.sort_index()
    df_mean[('mean', 'not-enough')] = df_not_enough.mean(axis = 0, skipna = True)
    df_mean[('median', 'not-enough' )] = df_not_enough.median(axis = 0, skipna = True)
    df_mean[('std', 'not-enough' )] = df_not_enough.std(axis = 0, skipna = True)
    print('n enough', len(new_df_dict_enough.keys()))
    print('n not enough', len(new_df_dict_not_enough.keys()))
    
    df_total = pd.DataFrame(df_total).T
    return df_mean, df_total

# %%
metrics = [
            'proportion',
            'diversity', 
           'coherence', 
           'dist-mean', 'dist-max', 
           'str-mean', 'str-max'
          ]


evidence_type = 'all' #'prop-specific'#, 'non-specific', 'u']
#model_name = 'giga_full_updated'
model_name = 'wiki_updated'
df_mean, df_total = get_comparison_evidence(evidence_type, model_name, metrics)
df_mean.round(4).T.sort_index()
#df_total.sort_values('cl')
#df_mean
# Out:
# all
# n enough 5
# n not enough 10
#                    proportion  diversity  coherence  dist-mean  dist-max  \
# mean   enough             1.0   296.4000     0.1349     0.6649    0.8837
#        not-enough         1.0  1087.1000     0.1098     0.5945    0.8317
# median enough             1.0   122.0000     0.1311     0.6610    0.8926
#        not-enough         1.0   927.0000     0.1008     0.5882    0.8163
# std    enough             0.0   269.2727     0.0141     0.0383    0.0546
#        not-enough         0.0  1002.8202     0.0176     0.0666    0.0700
#
#                    str-mean  str-max
# mean   enough        0.0058   0.0449
#        not-enough    0.0036   0.0357
# median enough        0.0056   0.0436
#        not-enough    0.0028   0.0373
# std    enough        0.0021   0.0074
#        not-enough    0.0020   0.0104

# %%
df_total.sort_values('cl')
# Out:
#                 proportion diversity  coherence dist-mean  dist-max  \
# warm                     1      1181  0.0996022  0.505907  0.758864
# black                    1       820   0.097678  0.615303  0.773284
# red                      1      1275   0.100407  0.537008  0.780208
# sweet                    1        26   0.150881  0.689588   0.80821
# hot                      1        92   0.129011  0.631017  0.830864
# green                    1       550   0.113325  0.553604  0.843946
# blue                     1      1819  0.0983739  0.672057         1
# roll                     1      3484  0.0969261  0.657345  0.888729
# cold                     1       590    0.11094  0.522039  0.812768
# round                    1      1034   0.101197  0.561045  0.819798
# square                   1       441    0.11639  0.626195  0.882311
# used_in_cooking          1       705   0.128794  0.674304  0.943222
# juicy                    1       122   0.149918  0.638359   0.79516
# female                   1       109   0.131121  0.660967    0.8926
# wheels                   1       105   0.148328  0.724589  0.905322
#
#                    str-mean    str-max     cl
# warm             0.00304041  0.0559694  False
# black            0.00247025  0.0429802  False
# red              0.00210826   0.029776  False
# sweet            0.00798246  0.0366528  False
# hot              0.00654335  0.0294876  False
# green            0.00289506  0.0187873  False
# blue             0.00197607  0.0253429  False
# roll             0.00247937   0.041851  False
# cold             0.00359904  0.0378891  False
# round            0.00280233  0.0385253  False
# square           0.00339449  0.0523331   True
# used_in_cooking  0.00458397  0.0521888   True
# juicy            0.00640241  0.0352288   True
# female           0.00558611  0.0411562   True
# wheels           0.00903054  0.0436421   True

# %%
evidence_type = 'prop-specific'#, 'non-specific', 'u']
df_mean, df_total = get_comparison_evidence(evidence_type, model_name, metrics)
df_mean.round(4).T.sort_index()
#df_total.sort_values('cl')
# Out:
# prop-specific
# n enough 6
# n not enough 10
#                    proportion  diversity  coherence  dist-mean  dist-max  \
# mean   enough          0.0326     5.8333     0.3409     0.7629    0.8215
#        not-enough      0.0150     3.9000     0.1589     0.6834    0.7400
# median enough          0.0181     5.5000     0.3846     0.7652    0.8269
#        not-enough      0.0036     3.0000     0.2031     0.6856    0.7773
# std    enough          0.0317     2.9944     0.1813     0.0559    0.0478
#        not-enough      0.0277     3.3483     0.1437     0.1297    0.1155
#
#                    str-mean  str-max
# mean   enough        0.0129   0.0199
#        not-enough    0.0101   0.0154
# median enough        0.0093   0.0227
#        not-enough    0.0096   0.0142
# std    enough        0.0116   0.0114
#        not-enough    0.0045   0.0079

# %%
df_total.sort_values('cl')
# Out:
#                   proportion diversity coherence dist-mean  dist-max  \
# warm              0.00592718         7  0.338158  0.459522  0.528743
# black             0.00487805         4   0.27363  0.613907  0.773284
# red              0.000784314         1         0  0.780208  0.780208
# sweet              0.0384615         1         0   0.78555   0.78555
# hot                0.0869565         8  0.232203  0.702513  0.830864
# green             0.00181818         1         0  0.843946  0.843946
# blue             0.000549753         1         0  0.830071  0.830071
# roll              0.00287026        10  0.256339  0.668639  0.774423
# cold              0.00338983         2  0.314954  0.523592  0.535868
# round             0.00386847         4  0.173969  0.625804  0.716757
# fly                0.0909091         5  0.384597  0.812303  0.876954
# wings              0.0180723         6  0.538477  0.749819  0.799179
# used_in_cooking     0.012766         9    0.4121  0.768121  0.854655
# juicy             0.00819672         1         0  0.762223  0.762223
# made_of_wood       0.0181087         9  0.384678    0.6645  0.778061
# wheels              0.047619         5  0.325293  0.820329  0.858005
#
#                    str-mean     str-max     cl
# warm              0.0033631  0.00536185  False
# black             0.0065165   0.0174455  False
# red               0.0169457   0.0169457  False
# sweet              0.015178    0.015178  False
# hot               0.0133791   0.0294876  False
# green             0.0106611   0.0106611  False
# blue              0.0132659   0.0132659  False
# roll             0.00855531   0.0273939  False
# cold             0.00757405   0.0099351  False
# round            0.00529467  0.00791909  False
# fly              0.00402524  0.00519446   True
# wings              0.005038  0.00757513   True
# used_in_cooking   0.0079763   0.0228222   True
# juicy             0.0352288   0.0352288   True
# made_of_wood      0.0107188   0.0225764   True
# wheels            0.0143816   0.0258542   True

# %%
evidence_type = 'non-specific'#, 'non-specific', 'u']
df_mean, df_total = get_comparison_evidence(evidence_type, model_name, metrics)
df_mean.round(4).T.sort_index()
# Out:
# non-specific
# n enough 7
# n not enough 12
#                    proportion  diversity  coherence  dist-mean  dist-max  \
# mean   enough          0.2956    87.7143     0.2580     0.7293    0.8832
#        not-enough      0.0871    79.2500     0.1683     0.6073    0.7599
# median enough          0.2703    36.0000     0.2733     0.7279    0.8684
#        not-enough      0.0603    81.0000     0.1415     0.5860    0.7503
# std    enough          0.2199   124.3741     0.0512     0.0479    0.0479
#        not-enough      0.0644    48.8600     0.0486     0.0660    0.0463
#
#                    str-mean  str-max
# mean   enough        0.0101   0.0420
#        not-enough    0.0054   0.0241
# median enough        0.0096   0.0428
#        not-enough    0.0053   0.0224
# std    enough        0.0022   0.0164
#        not-enough    0.0026   0.0122

# %%
evidence_type = 'u'#, 'non-specific', 'u']
df_mean, df_total = get_comparison_evidence(evidence_type, model_name, metrics)
df_mean.round(4).T.sort_index()
# Out:
# u
# n enough 3
# n not enough 12
#                    proportion  diversity  coherence  dist-mean  dist-max  \
# mean   enough          0.9549  1222.6667     0.0970     0.6168    0.9753
#        not-enough      0.9044  1195.1667     0.1009     0.5911    0.8279
# median enough          0.9574  1327.0000     0.0968     0.6440    1.0000
#        not-enough      0.9284   994.5000     0.0976     0.5785    0.8310
# std    enough          0.0076   284.2434     0.0054     0.0663    0.0428
#        not-enough      0.0724  1044.3117     0.0125     0.0597    0.0583
#
#                    str-mean  str-max
# mean   enough        0.0023   0.0416
#        not-enough    0.0027   0.0314
# median enough        0.0020   0.0319
#        not-enough    0.0026   0.0332
# std    enough        0.0007   0.0192
#        not-enough    0.0009   0.0163

# %% [markdown]
# # Overview relations

# %%
metrics = ['proportion', 'diversity', 'coherence',
            'dist-mean', 'dist-max', 'str-mean', 'str-max']
level = 'relations'
evidence_type = 'prop-specific'
model_name = 'giga_full_updated'
df = get_overview(metrics, level, model_name, evidence_type)
df = utils.raw_to_distance(df, score_names = metrics, reference_name = 'all', 
                           score = 'dist-percent', sum_scores = ['sum', 'bin'])
df['sum'] = df.sum(axis=1)
df.round(6)
# Out:
#                          proportion  diversity  coherence  dist-mean  \
# pos                       -0.472386  -0.500000   0.071302  -0.023468
# neg                             NaN        NaN   0.143935  -0.074833
# all                        0.000000   0.000000   0.000000   0.000000
# some                      -0.730388  -0.500000   0.222055  -0.039449
# few                             NaN        NaN   0.143935  -0.074833
# evidence                  -0.432051  -0.500000   0.071302  -0.013354
# no_evidence_pos           -0.920131  -0.750000   0.591446  -0.093247
# no_evidence_neg                 NaN        NaN   0.097120  -0.057819
# implied_category          -0.751580  -0.500000  -0.047619  -0.001321
# typical_of_concept        -0.478179   0.333333   0.168314   0.018863
# affording_activity         0.104584  -0.270833   0.536993   0.019400
# afforded_usual             5.169696  -0.500000   0.899434   0.068265
# afforded_unusual          -0.890939  -0.625000   0.715902  -0.134553
# variability_limited       -0.738915  -0.500000   0.715902   0.018863
# variability_open          -0.914210  -0.683333   1.287870  -0.085285
# variability_open_scalar   -0.440681   0.000000  -0.211955  -0.145496
# rare                            NaN        NaN   0.830296   0.016675
# unusual                         NaN        NaN   0.524889  -0.099893
# impossible                      NaN        NaN  -0.013979  -0.013354
# creative                        NaN        NaN   0.143935  -0.034710
# all-reference              0.011577   2.000000   0.437088   0.777216
#
#                          dist-max  str-mean   str-max        sum       bin
# pos                     -0.021723 -0.175199 -0.290890  -1.471274  0.142857
# neg                     -0.053654 -0.809087 -0.829011  -1.747181  0.200000
# all                      0.000000  0.000000  0.000000   0.000000  0.000000
# some                    -0.044725 -0.302367 -0.489796  -2.011052  0.142857
# few                     -0.053654 -0.809087 -0.829011  -1.747181  0.200000
# evidence                -0.021723 -0.174682 -0.262281  -1.380331  0.142857
# no_evidence_pos         -0.073916 -0.566273 -0.711933  -2.741775  0.142857
# no_evidence_neg         -0.052993 -0.825176 -0.849827  -1.826434  0.200000
# implied_category        -0.029476 -0.801536 -0.870005  -3.430329  0.000000
# typical_of_concept       0.000000  1.803397  0.812856   3.752666  0.714286
# affording_activity      -0.021723  0.042418 -0.403223   0.580132  0.571429
# afforded_usual           0.040527  7.140818  3.196142  19.159866  0.857143
# afforded_unusual        -0.169903 -0.808623 -0.902286  -3.074744  0.142857
# variability_limited     -0.021723 -0.291879 -0.493033  -1.212326  0.285714
# variability_open        -0.073916 -0.394293 -0.665113  -1.603749  0.142857
# variability_open_scalar -0.078766 -0.491932 -0.434506  -2.060956  0.000000
# rare                    -0.024852 -0.446019 -0.736716  -0.032740  0.400000
# unusual                 -0.099301 -0.829412 -0.847578  -1.421554  0.200000
# impossible              -0.049689 -0.885573 -0.893409  -2.227205  0.000000
# creative                -0.074138 -0.669449 -0.780369  -1.497676  0.200000
# all-reference            0.810314  0.006778  0.017179   5.640173  1.000000

# %%
metrics = ['proportion', 'diversity', 'coherence',
           'dist-mean', 'dist-max', 'str-mean', 'str-max']
level = 'relations'
evidence_type = 'prop-specific'
model_name = 'wiki_updated'
df = get_overview(metrics, level, model_name, evidence_type)
df = utils.raw_to_distance(df, score_names = metrics, reference_name = 'all', 
                           score = 'dist-percent', sum_scores = ['sum', 'bin'])
df['sum'] = df.sum(axis=1)
df.round(4)
# Out:
#                             proportion  diversity  coherence  dist-mean  \
# pos                            -0.4847     0.0000     0.1151    -0.0107
# neg                                NaN        NaN     0.2009    -0.0521
# all                             0.0000     0.0000     0.0000     0.0000
# some                           -0.6565     0.0000     0.1744    -0.0526
# few                                NaN        NaN     0.2009    -0.0521
# evidence                       -0.4023     0.0000     0.1151    -0.0110
# no_evidence_pos                -0.8933    -0.5000     0.6056    -0.0791
# no_evidence_neg                    NaN        NaN     0.1744    -0.0415
# implied_category               -0.7373    -0.2500    -0.1343    -0.0929
# typical_of_concept              3.1889     1.6667     0.0358     0.0819
# affording_activity              4.3869     0.1250    -0.1316     0.0894
# afforded_usual                     NaN        NaN        NaN        NaN
# afforded_unusual               -0.8792    -0.1250     0.6726    -0.1181
# variability_limited            -0.6326     0.0000     0.5847     0.0053
# variability_open               -0.8895     0.0000     1.2302     0.0948
# variability_limited_scalar      4.7469     1.0000     0.1692    -0.0521
# variability_open_scalar        -0.6026     0.0000    -0.1247    -0.3094
# rare                               NaN        NaN     0.6171     0.0053
# unusual                            NaN        NaN     0.4868    -0.0616
# impossible                         NaN        NaN     0.2124    -0.0108
# creative                           NaN        NaN     0.8252    -0.1312
# all-reference                   0.0084     1.0000     0.4484     0.7582
#
#                             dist-max  str-mean  str-max      sum     bin
# pos                          -0.0068   -0.0650  -0.1528  -0.5484  0.1429
# neg                          -0.0297   -0.7618  -0.7804  -1.5077  0.2000
# all                           0.0000    0.0000   0.0000   0.0000  0.0000
# some                         -0.0095   -0.1093  -0.3254  -0.9760  0.1429
# few                          -0.0297   -0.7618  -0.7804  -1.5077  0.2000
# evidence                     -0.0068   -0.0719  -0.1322  -0.4390  0.1429
# no_evidence_pos              -0.0156   -0.2662  -0.5349  -1.7810  0.1429
# no_evidence_neg              -0.0159   -0.8040  -0.8221  -1.6110  0.2000
# implied_category             -0.0654   -0.3355  -0.6771  -2.6202  0.0000
# typical_of_concept            0.0643   -0.2544  -0.6225   5.4694  0.7143
# affording_activity            0.0922    0.6232  -0.2801   6.3200  0.7143
# afforded_usual                   NaN       NaN      NaN   0.0000  0.0000
# afforded_unusual             -0.1275   -0.7847  -0.8634  -2.4003  0.1429
# variability_limited          -0.0118   -0.0481  -0.2885  -0.1612  0.2857
# variability_open              0.0567    0.0304  -0.2211   0.9159  0.5714
# variability_limited_scalar   -0.0847    2.6216   5.1009  16.1450  0.7143
# variability_open_scalar      -0.3178   -0.5835  -0.6048  -2.9060  0.0000
# rare                         -0.0297   -0.4613  -0.6400  -0.2102  0.4000
# unusual                      -0.0654   -0.7910  -0.8375  -1.3225  0.2000
# impossible                   -0.0110   -0.8872  -0.8997  -1.7156  0.2000
# creative                     -0.1614   -0.8625  -0.8808  -1.2529  0.2000
# all-reference                 0.7856    0.0056   0.0135   4.4510  1.0000
