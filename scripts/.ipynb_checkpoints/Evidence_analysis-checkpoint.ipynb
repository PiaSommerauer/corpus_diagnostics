# %%
import utils
import get_evidence_prop_div

import pandas as pd
import os 

pd.set_option('display.max_rows', None)

# %% [markdown]
# # Proportion of evidence

# %%
model_name = 'giga_full_updated'
df = get_evidence_prop_div.get_evidence_prop_div_properties(model_name, cnt = 'prop')

df = utils.raw_to_distance(df)
df.round(4)
# Out:
#                  prop-specific  non-specific       p       l       n       i  \
# square                     NaN       -0.0333     NaN     NaN     NaN -0.0106
# warm                   -0.0013       -0.0227 -0.0003 -0.0014 -0.0031 -0.0091
# black                  -0.0038       -0.0280 -0.0013 -0.0019     NaN -0.0118
# red                    -0.0050       -0.0221 -0.0016     NaN     NaN -0.0015
# fly                     0.0039       -0.0317  0.0041 -0.0007 -0.0030 -0.0434
# dangerous               0.0151        0.0229 -0.0004  0.0098  0.0022 -0.0123
# wings                   0.0069        0.0670  0.0014  0.0061     NaN -0.0036
# sweet                   0.0516        0.4670  0.0549     NaN     NaN  0.4910
# hot                     0.0302        0.1861  0.0216     NaN  0.0078  0.1267
# used_in_cooking         0.0084        0.5553  0.0048  0.0007 -0.0006  0.2768
# juicy                  -0.0031        0.0476  0.0003     NaN     NaN  0.0568
# green                  -0.0038        0.0885 -0.0005     NaN     NaN  0.0987
# made_of_wood           -0.0005       -0.0173  0.0029     NaN     NaN -0.0277
# blue                   -0.0047       -0.0011 -0.0013     NaN     NaN  0.0185
# yellow                  0.0137       -0.0181  0.0170     NaN     NaN  0.0059
# roll                   -0.0030       -0.0401 -0.0009 -0.0015     NaN -0.0274
# female                  0.0611        0.2353     NaN  0.0639     NaN  0.1037
# cold                    0.0000       -0.0139 -0.0013     NaN  0.0006 -0.0074
# round                  -0.0017        0.0011 -0.0003 -0.0009     NaN  0.0213
# wheels                  0.0108        0.0717  0.0060  0.0054     NaN  0.0015
# lay_eggs                0.0215        0.1944  0.0248     NaN     NaN  0.1239
# swim                   -0.0048       -0.0375 -0.0015     NaN     NaN -0.0431
# median                  0.0056        0.0758  0.0022  0.0028  0.0041  0.0518
#
#                       r       b       u
# square          -0.0162     NaN  0.0363
# warm            -0.0071     NaN  0.0214
# black           -0.0097     NaN  0.0292
# red             -0.0142     NaN  0.0245
# fly              0.0150 -0.0129  0.0253
# dangerous        0.0363 -0.0107 -0.0405
# wings            0.0503  0.0107 -0.0765
# sweet               NaN     NaN -0.5212
# hot              0.0658     NaN -0.2188
# used_in_cooking  0.2849     NaN -0.5663
# juicy           -0.0028     NaN -0.0471
# green           -0.0037     NaN -0.0872
# made_of_wood     0.0168     NaN  0.0152
# blue            -0.0131     NaN  0.0032
# yellow              NaN     NaN  0.0019
# roll            -0.0063     NaN  0.0405
# female              NaN  0.1395 -0.2989
# cold             0.0000     NaN  0.0113
# round           -0.0137     NaN -0.0019
# wheels           0.0767     NaN -0.0851
# lay_eggs         0.0770     NaN -0.2185
# swim             0.0121     NaN  0.0397
# median           0.0176  0.0161  0.9212

# %%
model_name = 'wiki_updated'
df = get_evidence_prop_div.get_evidence_prop_div_properties(model_name, cnt = 'prop')

df = utils.raw_to_distance(df)
df.round(4)
# Out:
#                  prop-specific  non-specific       p       l       n       i  \
# square                     NaN       -0.0311     NaN     NaN     NaN -0.0099
# warm                   -0.0023       -0.0269 -0.0010 -0.0013     NaN -0.0218
# black                  -0.0033       -0.0227 -0.0007 -0.0039 -0.0004 -0.0088
# red                    -0.0074       -0.0217 -0.0011     NaN     NaN -0.0020
# fly                     0.0827        0.2327  0.0709  0.0118     NaN  0.0902
# dangerous               0.0014        0.0154 -0.0003  0.0000 -0.0001 -0.0208
# wings                   0.0099        0.0590     NaN  0.0117     NaN  0.0109
# sweet                   0.0303        0.2900  0.0366     NaN     NaN  0.3112
# hot                     0.0788        0.0902  0.0199  0.0371  0.0201  0.0461
# used_in_cooking         0.0046        0.2728  0.0010 -0.0035  0.0054  0.1138
# juicy                   0.0000        0.0939  0.0063     NaN     NaN  0.0905
# green                  -0.0064        0.0436 -0.0001     NaN     NaN  0.0502
# made_of_wood            0.0099       -0.0262  0.0162     NaN     NaN -0.0432
# blue                   -0.0076       -0.0154 -0.0013     NaN     NaN  0.0013
# yellow                     NaN       -0.0225     NaN     NaN     NaN -0.0013
# roll                   -0.0053       -0.0602 -0.0010 -0.0044     NaN -0.0507
# female                  0.0193        0.0797  0.0073  0.0120     NaN  0.0550
# cold                   -0.0048       -0.0488 -0.0002     NaN  0.0001 -0.0327
# round                  -0.0043       -0.0530  0.0001 -0.0054 -0.0007 -0.0328
# wheels                  0.0394        0.1625  0.0267  0.0127     NaN  0.0123
# lay_eggs                   NaN        0.4054     NaN     NaN     NaN  0.2727
# swim                   -0.0070       -0.0505 -0.0007     NaN     NaN -0.0540
# median                  0.0082        0.0946  0.0019  0.0064  0.0016  0.0734
#
#                       r       b       u
# square              NaN     NaN  0.0373
# warm            -0.0119  0.0002  0.0294
# black           -0.0173     NaN  0.0250
# red             -0.0231     NaN  0.0293
# fly              0.1390     NaN -0.3151
# dangerous        0.0328     NaN -0.0165
# wings            0.0416 -0.0002 -0.0686
# sweet               NaN     NaN -0.3200
# hot              0.0406     NaN -0.1687
# used_in_cooking  0.1541 -0.0018 -0.2771
# juicy           -0.0001     NaN -0.0937
# green           -0.0101     NaN -0.0369
# made_of_wood     0.0136     NaN  0.0165
# blue            -0.0203     NaN  0.0228
# yellow              NaN     NaN  0.0310
# roll            -0.0129     NaN  0.0658
# female              NaN  0.0427 -0.0988
# cold            -0.0196     NaN  0.0539
# round           -0.0237     NaN  0.0576
# wheels           0.1468     NaN -0.2017
# lay_eggs         0.1292     NaN -0.3969
# swim             0.0001     NaN  0.0578
# median           0.0246  0.0032  0.8969

# %%
# concepts 

# analysis_name = 'proportion'
# model_name = 'giga_full_updated'

# properties = utils.get_properties()  
# df = get_evidence_prop_div.get_evidence_prop_div_concepts(model_name, properties, cnt = 'prop')
# # to file
# path_dir = f'../analysis/{model_name}/pairs/'
# os.makedirs(path_dir, exist_ok=True)
# path_file = f'{path_dir}/{analysis_name}.csv'
# df.to_csv(path_file)

# %%
# load prop data on pair level

from itertools import permutations
import os
import numpy as np

def load_relation_pairs(combination, order=True):
    
    all_pairs = set()
    
    path_dir = '../data/relations'
    if order == True:
        name = '-'.join(combination)
        paths = [f'{path_dir}/{name}.txt']
    else:
        perms = list(permutations(combination, len(combination)))
        paths = []
        for perm in perms:
            name = '-'.join(perm)
            paths.append(f'{path_dir}/{name}.txt')
    
    for path in paths:
        if os.path.isfile(path):
            with open(path) as infile:
                lines = infile.read().strip().split('\n')
            pairs = [(l.split(',')[0], l.split(',')[1]) for l in lines]
            all_pairs.update(pairs)
    return all_pairs


def str_to_tuple(pair_str):
    
    pair_str = pair_str.strip('(').strip(')').replace("'", '')
    pair_list = pair_str.split(', ')
    pair_t = tuple(pair_list)
    return pair_t


def load_scores(analysis_name, model_name):

    path_dir = f'../analysis/{model_name}/pairs/'
    path_file = f'{path_dir}/{analysis_name}.csv'
    df = pd.read_csv(path_file)#.fillna(0.0)

    pair_score_dict = dict()
    for i, row in df.iterrows():
        pair = row['pair']
        pair = str_to_tuple(pair)
        score = row['prop-specific'] 
        pair_score_dict[pair] = score
    return pair_score_dict


def relation_overview(pair_score_dict):

    relations =  ['pos', 'neg', 'all', 'some', 'few',
                         'evidence', 'no_evidence_pos', 'no_evidence_neg',
                         'implied_category', 
                         'typical_of_concept', 'typical_of_property', 
                         'affording_activity', 'afforded_usual', 'afforded_unusual',
                         'variability_limited', 'variability_open',
                         'variability_limited_scalar', 'variability_open_scalar',
                         'rare', 'unusual', 'impossible', 'creative']

    table = []
    for rel in relations:
        pairs = load_relation_pairs([rel], order=False)
        scores = []
        for pair in pairs:
            if pair in pair_score_dict.keys():
                scores.append(pair_score_dict[pair])
        if len(scores) > 0:
            med = np.nanmedian(scores)
            d = dict()
            d['relation'] = rel
            d['prop-specific'] = med
            d['n_pairs'] = len(scores)
            table.append(d)

    df = pd.DataFrame(table).set_index('relation')
    return df

analysis_name = 'proportion'
model_name = 'giga_full_updated'
pair_score_dict = load_scores(analysis_name, model_name)
df = relation_overview(pair_score_dict)
df = utils.raw_to_distance(df, reference_name = 'pos')
df.round(6)
# Out:
#                          prop-specific  n_pairs
# pos                           0.000000   1707.0
# neg                          -0.006211   1221.0
# all                           0.005492    995.0
# some                         -0.003089    712.0
# few                          -0.006211   1221.0
# evidence                     -0.000002   1516.0
# no_evidence_pos              -0.005847    229.0
# no_evidence_neg              -0.006211   1183.0
# implied_category             -0.003335     14.0
# typical_of_concept           -0.000169      3.0
# affording_activity            0.006578      4.0
# afforded_usual                0.065218      2.0
# afforded_unusual             -0.004948     19.0
# variability_limited          -0.003188    104.0
# variability_open             -0.005217     76.0
# variability_open_scalar       0.000265     95.0
# rare                         -0.006211     18.0
# unusual                      -0.006211     75.0
# impossible                   -0.006211    265.0
# creative                     -0.006211     21.0
# median                       -0.006211   2929.0
# pos-reference                 0.006211   1707.0
