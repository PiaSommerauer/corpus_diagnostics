# %%
import utils
import relations

import pandas as pd
import os
import csv

from collections import defaultdict

pd.set_option('display.max_rows', None)

# %%
#'../analysis/wiki_full/annotation-tfidf-top_3_3-raw-10000-categories/square/annotation-updated-done.csv

# %% [markdown]
# # Overview properties

# %%
def get_overview(metrics, level, model_name, evidence_type):
    path_dir = f'../analysis/{model_name}/{level}'
    overview_dict = defaultdict(dict)
    for metric in metrics:
        path = f'{path_dir}/{metric}.csv'
        with open(path) as infile:
            data = list(csv.DictReader(infile))
        for d in data:
            prop = d['']
            sc = d[evidence_type]
            overview_dict[prop][metric] = float(sc)
    df = pd.DataFrame(overview_dict)
    return df.T


metrics = ['proportion', 'diversity', 'coherence']
level = 'properties'
evidence_type = 'prop-specific'
model_name = 'giga_full_updated'
df = get_overview(metrics, level, model_name, evidence_type)
df.round(2)
# Out:
#                   proportion  diversity  coherence
# square                 -0.01       -2.5      -0.29
# warm                   -0.00        6.5      -0.01
# black                  -0.00       -0.5      -0.13
# red                    -0.00       -1.5      -0.29
# fly                     0.00        6.5       0.06
# dangerous               0.02       20.5      -0.05
# wings                   0.01        4.5       0.11
# sweet                   0.05       -0.5       0.18
# hot                     0.03        0.5      -0.01
# used_in_cooking         0.01        5.5       0.10
# juicy                  -0.00       -0.5       0.35
# green                  -0.00       -1.5      -0.29
# made_of_wood           -0.00        1.5       0.16
# blue                   -0.00       -0.5       0.01
# yellow                  0.01       -1.5      -0.29
# roll                   -0.00        7.5      -0.08
# female                  0.06        0.5       0.29
# cold                    0.00        3.5       0.05
# round                  -0.00       -0.5      -0.16
# wheels                  0.01        1.5       0.10
# lay_eggs                0.02       -0.5       0.54
# swim                   -0.00       -1.5      -0.29
# median                  0.00        0.0       0.00
# median-reference        0.01        2.5       0.29

# %%
metrics = ['proportion', 'diversity', 'coherence']
level = 'properties'
evidence_type = 'non-specific'
model_name = 'giga_full_updated'
df = get_overview(metrics, level, model_name, evidence_type)
df.round(2)
# Out:
#                   proportion  diversity  coherence
# square                 -0.03        4.5       0.01
# warm                   -0.02       52.5      -0.03
# black                  -0.03       -4.5      -0.04
# red                    -0.02       35.5      -0.03
# fly                    -0.03      -17.5      -0.03
# dangerous               0.02       50.5      -0.03
# wings                   0.07       20.5      -0.01
# sweet                   0.47      -40.5       0.15
# hot                     0.19      -37.5       0.05
# used_in_cooking         0.56      301.5       0.07
# juicy                   0.05       40.5       0.13
# green                   0.09       35.5       0.04
# made_of_wood           -0.02      -13.5      -0.03
# blue                   -0.00      107.5      -0.04
# yellow                 -0.02      -56.5       0.11
# roll                   -0.04       79.5      -0.02
# female                  0.24      -45.5       0.11
# cold                   -0.01        7.5      -0.02
# round                   0.00      -19.5       0.05
# wheels                  0.07      -23.5       0.05
# lay_eggs                0.19      -39.5       0.12
# swim                   -0.04       -6.5      -0.04
# median                  0.00        0.0       0.00
# median-reference        0.08       59.5       0.17
